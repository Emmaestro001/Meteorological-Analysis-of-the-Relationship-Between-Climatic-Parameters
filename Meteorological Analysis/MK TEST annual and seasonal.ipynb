# %%
#IMPORT NECESSARY PACAKAGES
import numpy as np
import pandas as pd
import pymannkendall as mk
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import ExcelWriter
from pandas import ExcelFile
from matplotlib.figure import Figure

# %%
#IMPORT ANNUAL DATA FOR ALL PARANETERS 
result = pd.read_excel("EPT.xlsx", 'Sheet2',index_col= 'YEAR')
result.head()
# Out:
#       Atm. Pressure  Rel. Humidity   Min Temp.   Max. Temp    Av. Temp  \
# YEAR
# 2005    1005.150000      87.146704  296.679058  303.776363  300.227711
# 2006    1005.383333      85.378802  296.722088  303.608641  300.165364
# 2007    1005.500000      84.838492  296.387410  303.815156  300.101283
# 2008    1005.441667      85.996975  296.464788  303.963107  300.213948
# 2009    1005.825000      83.357245  296.619124  303.959850  300.289487
#
#       Dew. Pt. Temp.  Spec. Humidity  Sat. Vap. Pressure  Vap. Pressure  \
# YEAR
# 2005      297.836003        0.951733           35.858716      31.178205
# 2006      297.409264        0.950543           35.688221      30.367505
# 2007      297.273243        0.950184           35.582823      30.101655
# 2008      297.614787        0.951176           35.787115      30.721436
# 2009      297.140549        0.949655           35.955814      29.918425
#
#       Sat. Mixinr Ratio  Mixing Ratio  Temp. at lifting Con. Level  \
# YEAR
# ...

# %% [markdown]
# BEGIN CONDUCTING MANN-KENDALL TREND TEST FOR EACH PARAMETER

# %%
mk.original_test(result['Atm. Pressure'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='increasing', h=True, p=0.00012703221709875478, z=3.8321423101595125, Tau=0.7802197802197802, s=71.0, var_s=333.6666666666667, slope=0.14000000000002047, intercept=1004.8649999999999)

# %%
mk.original_test(result['Rel. Humidity'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.9128140271840748, z=-0.10948978029027179, Tau=-0.03296703296703297, s=-3.0, var_s=333.6666666666667, slope=-0.023196248196249124, intercept=85.83392510036003)

# %%
mk.original_test(result['Min Temp.'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.2735614117247491, z=-1.0948978029027179, Tau=-0.23076923076923078, s=-21.0, var_s=333.6666666666667, slope=-0.01824018275630561, intercept=296.6191925331496)

# %%
mk.original_test(result['Max. Temp'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='increasing', h=True, p=0.011793457077065028, z=2.518264946676251, Tau=0.5164835164835165, s=47.0, var_s=333.6666666666667, slope=0.06763844012453053, intercept=303.5218288324476)

# %%
mk.original_test(result['Av. Temp'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.7425568219265775, z=0.32846934087081536, Tau=0.07692307692307693, s=7.0, var_s=333.6666666666667, slope=0.02255824372759627, intercept=300.07420050055623)

# %%
mk.original_test(result['Dew. Pt. Temp.'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.5840703669455065, z=0.5474489014513589, Tau=0.12087912087912088, s=11.0, var_s=333.6666666666667, slope=0.01842669912413054, intercept=297.49381442805714)

# %%
result.head()
# Out:
#       Atm. Pressure  Rel. Humidity   Min Temp.   Max. Temp    Av. Temp  \
# YEAR
# 2005    1005.150000      87.146704  296.679058  303.776363  300.227711
# 2006    1005.383333      85.378802  296.722088  303.608641  300.165364
# 2007    1005.500000      84.838492  296.387410  303.815156  300.101283
# 2008    1005.441667      85.996975  296.464788  303.963107  300.213948
# 2009    1005.825000      83.357245  296.619124  303.959850  300.289487
#
#       Dew. Pt. Temp.  Spec. Humidity  Sat. Vap. Pressure  Vap. Pressure  \
# YEAR
# 2005      297.836003        0.951733           35.858716      31.178205
# 2006      297.409264        0.950543           35.688221      30.367505
# 2007      297.273243        0.950184           35.582823      30.101655
# 2008      297.614787        0.951176           35.787115      30.721436
# 2009      297.140549        0.949655           35.955814      29.918425
#
#       Sat. Mixinr Ratio  Mixing Ratio  Temp. at lifting Con. Level  \
# YEAR
# ...

# %%
mk.original_test(result['Spec. Humidity'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.38107448160929436, z=0.8759182423221743, Tau=0.18681318681318682, s=17.0, var_s=333.6666666666667, slope=5.962138509772099e-05, intercept=0.95080369133775)

# %%
mk.original_test(result['Sat. Vap. Pressure'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.7425568219265775, z=0.32846934087081536, Tau=0.07692307692307693, s=7.0, var_s=333.6666666666667, slope=0.034498422500041453, intercept=35.59867601359708)

# %%
mk.original_test(result['Vap. Pressure'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.5840703669455065, z=0.5474489014513589, Tau=0.12087912087912088, s=11.0, var_s=333.6666666666667, slope=0.025851009992652572, intercept=30.522590220306174)

# %%
mk.original_test(result['Sat. Mixinr Ratio'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.9128140271840748, z=0.10948978029027179, Tau=0.03296703296703297, s=3.0, var_s=333.6666666666667, slope=0.01922754351040532, intercept=22.86289378247654)

# %%
mk.original_test(result['Mixing Ratio'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.5840703669455065, z=0.5474489014513589, Tau=0.12087912087912088, s=11.0, var_s=333.6666666666667, slope=0.013197620234945166, intercept=19.484169815656248)

# %%
mk.original_test(result['Temp. at lifting Con. Level'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.4434214028640828, z=0.7664284620319025, Tau=0.16483516483516483, s=15.0, var_s=333.6666666666667, slope=0.02039095380040834, intercept=296.7776112484307)

# %%
result.head()
# Out:
#       Atm. Pressure  Rel. Humidity   Min Temp.   Max. Temp    Av. Temp  \
# YEAR
# 2005    1005.150000      87.146704  296.679058  303.776363  300.227711
# 2006    1005.383333      85.378802  296.722088  303.608641  300.165364
# 2007    1005.500000      84.838492  296.387410  303.815156  300.101283
# 2008    1005.441667      85.996975  296.464788  303.963107  300.213948
# 2009    1005.825000      83.357245  296.619124  303.959850  300.289487
#
#       Dew. Pt. Temp.  Spec. Humidity  Sat. Vap. Pressure  Vap. Pressure  \
# YEAR
# 2005      297.836003        0.951733           35.858716      31.178205
# 2006      297.409264        0.950543           35.688221      30.367505
# 2007      297.273243        0.950184           35.582823      30.101655
# 2008      297.614787        0.951176           35.787115      30.721436
# 2009      297.140549        0.949655           35.955814      29.918425
#
#       Sat. Mixinr Ratio  Mixing Ratio  Temp. at lifting Con. Level  \
# YEAR
# ...

# %%
mk.original_test(result['Potential Temp.'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=1.0, z=0.0, Tau=0.01098901098901099, s=1.0, var_s=333.6666666666667, slope=0.0010232809353567518, intercept=299.76489430374517)

# %%
mk.original_test(result['Equ. Potential Temp.'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.6614159170078631, z=0.43795912116108715, Tau=0.0989010989010989, s=9.0, var_s=333.6666666666667, slope=0.054567368651272354, intercept=356.9957966102703)

# %%
mk.original_test(result['Refractivity'], alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.4434214028640828, z=0.7664284620319025, Tau=0.16483516483516483, s=15.0, var_s=333.6666666666667, slope=0.15283894321411395, intercept=385.9805296540796)

# %%
#IMPORT SEASONAL DATA FOR ALL PARAMETERS 
seasonal = pd.read_excel("EPT.xlsx", 'Sheet3', index_col='DATE')
seasonal.head()
# Out:
#             Atm. Pressure  Rel. Humidity   Min Temp.   Max. Temp    Av. Temp  \
# DATE
# 2005-01-01         1004.0      69.064516  295.020968  305.795161  300.408065
# 2005-02-01         1003.7      80.535714  298.364286  307.185714  302.775000
# 2005-03-01         1002.4      90.741935  297.150000  305.569355  301.359677
# 2005-04-01         1003.9      91.033333  297.716667  305.650000  301.683333
# 2005-05-01         1005.5      91.290323  296.956452  304.343548  300.650000
#
#             Dew. Pt. Temp.  Spec. Humidity  Sat. Vap. Pressure  Vap. Pressure  \
# DATE
# 2005-01-01      294.239193        0.940696           36.152597      24.968616
# 2005-02-01      299.069002        0.955377           41.473141      33.400690
# 2005-03-01      299.701185        0.957059           38.215554      34.677534
# 2005-04-01      300.075432        0.957923           38.940165      35.448530
# 2005-05-01      299.101885        0.955395           36.667661      33.474026
#
# ...

# %% [markdown]
# CONDUCT SEASONAL MANN-KENDALL TEST FOR EACH PARAMETERS. TAKE THE PERIOD TO BE 12 (SIGNIFYING 12 MONTHS)

# %%
mk.seasonal_test(seasonal, alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='no trend', h=False, p=0.17811916484217094, z=1.346568748614579, Tau=0.018073377055412985, s=3803.0, var_s=7971997.666666665, slope=2.384433240087516e-05, intercept=297.0473293414661)

# %%
mk.seasonal_test(seasonal['Atm. Pressure'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.0, z=8.975022316189259, Tau=0.5173992673992674, s=565.0, var_s=3949.0, slope=0.13333333333332575, intercept=1004.8722222222223)

# %%
mk.seasonal_test(seasonal['Rel. Humidity'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='no trend', h=False, p=0.2356799134290375, z=-1.1858541225631423, Tau=-0.0695970695970696, s=-76.0, var_s=3999.9999999999995, slope=-0.038530465949820875, intercept=88.75144115890083)

# %%
mk.seasonal_test(seasonal['Min Temp.'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=0.0071197668994884555, z=-2.691189832563717, Tau=-0.1565934065934066, s=-171.0, var_s=3990.3333333333326, slope=-0.032258064516113905, intercept=296.6744623655913)

# %%
mk.seasonal_test(seasonal['Max. Temp'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=2.1247189452289206e-07, z=5.188081258071742, Tau=0.30128205128205127, s=329.0, var_s=3996.9999999999995, slope=0.06474654377880386, intercept=303.8962461597542)

# %%
mk.seasonal_test(seasonal['Av. Temp'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.03284245451023948, z=2.134003986288042, Tau=0.12454212454212454, s=136.0, var_s=4001.9999999999995, slope=0.016129032258056952, intercept=300.23212365591405)

# %%
mk.seasonal_test(seasonal['Dew. Pt. Temp.'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='no trend', h=False, p=0.6467360855443176, z=0.45830116739973514, Tau=0.027472527472527472, s=30.0, var_s=4003.9999999999995, slope=0.00749522510146167, intercept=297.66488425382175)

# %%
seasonal.head()
# Out:
#             Atm. Pressure  Rel. Humidity   Min Temp.   Max. Temp    Av. Temp  \
# DATE
# 2005-01-01         1004.0      69.064516  295.020968  305.795161  300.408065
# 2005-02-01         1003.7      80.535714  298.364286  307.185714  302.775000
# 2005-03-01         1002.4      90.741935  297.150000  305.569355  301.359677
# 2005-04-01         1003.9      91.033333  297.716667  305.650000  301.683333
# 2005-05-01         1005.5      91.290323  296.956452  304.343548  300.650000
#
#             Dew. Pt. Temp.  Spec. Humidity  Sat. Vap. Pressure  Vap. Pressure  \
# DATE
# 2005-01-01      294.239193        0.940696           36.152597      24.968616
# 2005-02-01      299.069002        0.955377           41.473141      33.400690
# 2005-03-01      299.701185        0.957059           38.215554      34.677534
# 2005-04-01      300.075432        0.957923           38.940165      35.448530
# 2005-05-01      299.101885        0.955395           36.667661      33.474026
#
# ...

# %%
mk.seasonal_test(seasonal['Spec. Humidity'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='no trend', h=False, p=0.7881918705922124, z=0.26865930502743096, Tau=0.016483516483516484, s=18.0, var_s=4003.9999999999995, slope=1.641239723051716e-05, intercept=0.9514076478162998)

# %%
mk.seasonal_test(seasonal['Sat. Vap. Pressure'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.03284245451023948, z=2.134003986288042, Tau=0.12454212454212454, s=136.0, var_s=4001.9999999999995, slope=0.033446545177911347, intercept=35.78533687630151)

# %%
mk.seasonal_test(seasonal['Vap. Pressure'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='no trend', h=False, p=0.6467360855443176, z=0.45830116739973514, Tau=0.027472527472527472, s=30.0, var_s=4003.9999999999995, slope=0.013162491216162224, intercept=30.737379977013003)

# %%
mk.seasonal_test(seasonal['Sat. Mixing Ratio'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='increasing', h=True, p=0.044745079996460824, z=2.0070430434402193, Tau=0.11721611721611722, s=128.0, var_s=4003.9999999999995, slope=0.019634527177392336, intercept=22.984561495278697)

# %%
mk.seasonal_test(seasonal['Mixing Ratio'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='no trend', h=False, p=0.7881918705922124, z=0.26865930502743096, Tau=0.016483516483516484, s=18.0, var_s=4003.9999999999995, slope=0.007095996344341018, intercept=19.57849470944263)

# %%
mk.seasonal_test(seasonal['Temp. at lifting Con. Level'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='no trend', h=False, p=0.5587299003730704, z=0.584729075647938, Tau=0.0347985347985348, s=38.0, var_s=4003.9999999999995, slope=0.005864386610158786, intercept=297.16360256760294)

# %%
mk.seasonal_test(seasonal['Potential Temp.'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='no trend', h=False, p=0.5587299003730704, z=0.584729075647938, Tau=0.0347985347985348, s=38.0, var_s=4003.9999999999995, slope=0.0048283847942182465, intercept=299.89403843986247)

# %%
mk.seasonal_test(seasonal['Equ. Potential Temp.'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='no trend', h=False, p=0.624198899548932, z=0.4899081444617859, Tau=0.029304029304029304, s=32.0, var_s=4003.9999999999995, slope=0.02625702359264608, intercept=356.81910999929227)

# %%
mk.seasonal_test(seasonal['Refractivity'], alpha=0.05, period=12)
# Out:
# Seasonal_Mann_Kendall_Test(trend='no trend', h=False, p=0.4387114646307575, z=0.7743709380202421, Tau=0.045787545787545784, s=50.0, var_s=4003.9999999999995, slope=0.06660908018350872, intercept=388.97621155286663)

# %%
seasonal.head()
# Out:
#             Atm. Pressure  Rel. Humidity   Min Temp.   Max. Temp    Av. Temp  \
# DATE
# 2005-01-01         1004.0      69.064516  295.020968  305.795161  300.408065
# 2005-02-01         1003.7      80.535714  298.364286  307.185714  302.775000
# 2005-03-01         1002.4      90.741935  297.150000  305.569355  301.359677
# 2005-04-01         1003.9      91.033333  297.716667  305.650000  301.683333
# 2005-05-01         1005.5      91.290323  296.956452  304.343548  300.650000
#
#             Dew. Pt. Temp.  Spec. Humidity  Sat. Vap. Pressure  Vap. Pressure  \
# DATE
# 2005-01-01      294.239193        0.940696           36.152597      24.968616
# 2005-02-01      299.069002        0.955377           41.473141      33.400690
# 2005-03-01      299.701185        0.957059           38.215554      34.677534
# 2005-04-01      300.075432        0.957923           38.940165      35.448530
# 2005-05-01      299.101885        0.955395           36.667661      33.474026
#
# ...

# %%
seasonal.plot(subplots=True, layout=(8,2), figsize=(14,6))
# Out:
# array([[<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>],
#        [<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>],
#        [<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>],
#        [<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>],
#        [<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>],
#        [<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>],
#        [<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>],
#        [<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>]],
#       dtype=object)

# %%
plot_cols = ['Av. Temp', 'Min Temp.', 'Max. Temp','Atm. Pressure']

seasonal[plot_cols].plot(kind='line', subplots=True, layout=(2, 2), figsize=(14,10), linestyle=':')
# Out:
# array([[<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>],
#        [<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>]],
#       dtype=object)
