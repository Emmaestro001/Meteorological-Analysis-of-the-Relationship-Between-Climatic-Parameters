# %%
#IMPORT NECESSARY PACKAGES

import numpy as np
import pandas as pd
import pymannkendall as mk
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import ExcelWriter
from pandas import ExcelFile
from matplotlib.figure import Figure

# %%
#IMPORT EXCEL SHEET FOR DRY SEASON
dry = pd.read_excel("EPT.xlsx", 'Sheet5', index_col='YEAR')
dry.head()
# Out:
#             Atm. Pressure  Rel. Humidity   Min Temp.   Max. Temp    Av. Temp  \
# YEAR
# 2005-01-01         1004.0      69.064516  295.020968  305.795161  300.408065
# 2005-02-01         1003.7      80.535714  298.364286  307.185714  302.775000
# 2005-11-01         1004.1      88.366667  296.683333  304.450000  300.566667
# 2005-12-01         1003.3      74.129032  296.472581  303.956452  300.214516
# 2006-01-01         1003.4      69.838710  297.730645  304.956452  301.343548
#
#             Dew. Pt. Temp.  Spec. Humidity  Sat. Vap. Pressure  Vap. Pressure  \
# YEAR
# 2005-01-01      294.239193        0.940696           36.152597      24.968616
# 2005-02-01      299.069002        0.955377           41.473141      33.400690
# 2005-11-01      298.471138        0.953781           36.489533      32.244584
# 2005-12-01      295.210332        0.944047           35.745093      26.497492
# 2006-01-01      295.315301        0.944381           38.179753      26.664247
#
#             Sat. Mixing Ratio  Mixing Ratio  Temp. at lifting Con. Level  \
# YEAR
# 2005-01-01          23.232826     15.862342                   292.748890
# 2005-02-01          26.807659     21.410123                   298.111382
# 2005-11-01          23.455095     20.635955                   297.911653
# 2005-12-01          22.977896     16.872034                   293.983002
# 2006-01-01          24.602324     16.979374                   293.845037
#
#             Potential Temp.  Equ. Potential Temp.  Refractivity
# YEAR
# 2005-01-01       300.067516            346.705390    363.102018
# 2005-02-01       302.457945            366.238181    393.874418
# 2005-11-01       300.217911            361.035802    393.083845
# 2005-12-01       299.933699            349.506217    369.583320
# 2006-01-01       301.053160            351.189483    368.501484

# %%
#IMPORT EXCEL SHEET FOR WET SEASON
wet = pd.read_excel("EPT.xlsx", 'Sheet6', index_col='YEAR')
wet.head()
# Out:
#             Atm. Pressure  Rel. Humidity   Min Temp.   Max. Temp    Av. Temp  \
# YEAR
# 2005-03-01         1002.4      90.741935  297.150000  305.569355  301.359677
# 2005-04-01         1003.9      91.033333  297.716667  305.650000  301.683333
# 2005-05-01         1005.5      91.290323  296.956452  304.343548  300.650000
# 2005-06-01         1005.9      91.600000  296.883333  302.250000  299.566667
# 2005-07-01         1008.2      94.645161  296.117742  301.440323  298.779032
#
#             Dew. Pt. Temp.  Spec. Humidity  Sat. Vap. Pressure  Vap. Pressure  \
# YEAR
# 2005-03-01      299.701185        0.957059           38.215554      34.677534
# 2005-04-01      300.075432        0.957923           38.940165      35.448530
# 2005-05-01      299.101885        0.955395           36.667661      33.474026
# 2005-06-01      298.087651        0.952651           34.410046      31.519603
# 2005-07-01      297.854815        0.951895           32.845620      31.086790
#
#             Sat. Mixing Ratio  Mixing Ratio  Temp. at lifting Con. Level  \
# YEAR
# 2005-03-01          24.651848     22.287780                   299.238599
# 2005-04-01          25.099091     22.766161                   299.622170
# 2005-05-01          23.539868     21.419016                   298.671324
# 2005-06-01          22.030096     20.119706                   297.681740
# 2005-07-01          20.945197     19.787933                   297.586132
#
#             Potential Temp.  Equ. Potential Temp.  Refractivity
# YEAR
# 2005-03-01       301.154862            367.227340    401.306456
# 2005-04-01       301.350515            368.938628    404.285039
# 2005-05-01       300.182549            363.344213    398.399700
# 2005-06-01       299.066971            358.033384    392.281081
# 2005-07-01       298.087317            355.812568    392.442543

# %% [markdown]
# BEGIN PLOTTING WET AND DRY SEASON TRENDS FOR EACH PARAMETER

# %%
plt.plot(dry['Atm. Pressure'], 'g.-',color='black', label="Dry season")
plt.plot(wet['Atm. Pressure'], 'r.:', label="wet season")


plt.xlabel('Time')
plt.ylabel("Atmospheric Pressure (hPa)")
plt.legend(bbox_to_anchor=(0.5, 1), loc="upper right")
plt.show()
#plt.xticks(Max.DATE[::2])

#plt.title('S', fontdict={'fontweight':'bold', 'fontsize':18})

# %%
plt.plot(dry['Rel. Humidity'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Rel. Humidity'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Relative Humidity (%)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Max. Temp'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Max. Temp'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Maximum Temperature (K)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Min Temp.'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Min Temp.'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Minimum Tempearature (K)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Av. Temp'], 'b.-', color='black', label="Dry season")
plt.plot(wet['Av. Temp'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Average  Tempearture (K)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Dew. Pt. Temp.'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Dew. Pt. Temp.'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Dew Point Temperature (K)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Spec. Humidity'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Spec. Humidity'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Specific Humidity")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Sat. Vap. Pressure'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Sat. Vap. Pressure'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Saturated Vapour Pressure (hPa)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Mixing Ratio'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Mixing Ratio'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Mixing Ratio")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Sat. Mixing Ratio'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Sat. Mixing Ratio'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Saturated Mixing Ratio")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Vap. Pressure'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Vap. Pressure'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Vapour Pressure (hPa)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Temp. at lifting Con. Level'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Temp. at lifting Con. Level'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Temp. at lifting Con. Level (K)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Potential Temp.'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Potential Temp.'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Potential Temperature (K)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Equ. Potential Temp.'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Equ. Potential Temp.'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Equivalent Potential Temperature (K)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.plot(dry['Refractivity'], 'g.-', color='black', label="Dry season")
plt.plot(wet['Refractivity'], 'r.:', label="wet season")

plt.xlabel('Time')
plt.ylabel("Refractivity (N-units)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()
